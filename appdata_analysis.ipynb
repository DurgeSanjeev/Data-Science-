# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
appdata=pd.read_csv("app.csv")
appdata
# Out:
#           id                                           app_name  \
# 0          2                        Sonic the Hedgehog™ Classic
# 1          3                                        Push'em all
# 2          5                                    Sky Fighters 3D
# 3          6                                        Robbery Bob
# 4          7                                     Shadow Fight 2
# ...      ...                                                ...
# 53727  53653  Omni Websites: Free Website Builder & Online S...
# 53728  53680                           Web Alert Expansion Pack
# 53729  53683  Reading Comprehension – GRE® Test Prep & Practice
# 53730  53707                     Soulspace Christian Meditation
# 53731  53733        Relax & Sleep Well: Hypnosis and Meditation
#
#                   genre  rating           reviews   cost_label  rate_5_pc  \
# 0                   NaN     4.1     193,898 total      Install    68.0272
# ...

# %%
appdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53732 entries, 0 to 53731
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                53732 non-null  int64
#  1   app_name          53675 non-null  object
#  2   genre             48654 non-null  object
#  3   rating            47688 non-null  float64
#  4   reviews           47688 non-null  object
#  5   cost_label        53653 non-null  object
#  6   rate_5_pc         47688 non-null  float64
#  7   rate_4_pc         47688 non-null  float64
#  8   rate_3_pc         47688 non-null  float64
#  9   rate_2_pc         47688 non-null  float64
#  10  rate_1_pc         47688 non-null  float64
#  11  updated           53675 non-null  object
#  12  size              53675 non-null  object
#  13  installs          53658 non-null  object
#  14  current_version   53660 non-null  object
#  15  requires_android  53643 non-null  object
# ...

# %%
appdata.columns
# Out:
# Index(['id', 'app_name', 'genre', 'rating', 'reviews', 'cost_label',
#        'rate_5_pc', 'rate_4_pc', 'rate_3_pc', 'rate_2_pc', 'rate_1_pc',
#        'updated', 'size', 'installs', 'current_version', 'requires_android',
#        'content_rating', 'in_app_products', 'offered_by'],
#       dtype='object')

# %%
appdata[["id","rating","size"]]
# Out:
#           id  rating                size
# 0          2     4.1                 61M
# 1          3     3.8                 41M
# 2          5     4.2                 19M
# 3          6     4.3                 42M
# 4          7     4.6                142M
# ...      ...     ...                 ...
# 53727  53653     3.4                4.0M
# 53728  53680     4.4                1.1M
# 53729  53683     4.4                3.1M
# 53730  53707     4.8                 29M
# 53731  53733     4.7  Varies with device
#
# [53732 rows x 3 columns]

# %%
appdata.head(20)
# appdata.tail(5)
# Out:
#     id                                           app_name   genre  rating  \
# 0    2                        Sonic the Hedgehog™ Classic     NaN     4.1
# 1    3                                        Push'em all  Action     3.8
# 2    5                                    Sky Fighters 3D  Action     4.2
# 3    6                                        Robbery Bob  Action     4.3
# 4    7                                     Shadow Fight 2  Action     4.6
# 5    8                     Cover Strike - 3D Team Shooter  Action     4.0
# 6    9                                        Om Nom: Run  Action     4.3
# 7   10  War Machines: Tank Battle - Army & Military Games  Action     4.4
# 8   11     Sniper 3D: Fun Offline Gun Shooting Games Free  Action     4.5
# 9   12                                     Hills of Steel  Action     4.2
# 10  13      Rope Frog Ninja Hero - Strange Gangster Vegas  Action     4.1
# 11  14                                       Swamp Attack  Action     4.6
# ...

# %%
appdata["app_name"][1:5]
# Out:
# 1        Push'em all
# 2    Sky Fighters 3D
# 3        Robbery Bob
# 4     Shadow Fight 2
# Name: app_name, dtype: object

# %%
appdata.iloc[4,3]
# Out:
# 4.6

# %%
appdata.loc[appdata["size"]>"61M"]
# Out:
#           id                                           app_name  \
# 6          9                                        Om Nom: Run
# 7         10  War Machines: Tank Battle - Army & Military Games
# 8         11     Sniper 3D: Fun Offline Gun Shooting Games Free
# 9         12                                     Hills of Steel
# 10        13      Rope Frog Ninja Hero - Strange Gangster Vegas
# ...      ...                                                ...
# 53711  53409             Diabetes Diary - Blood Glucose Tracker
# 53712  53411    Color Blindness Test, Ishihara Color Blind Test
# 53713  53436  Ebonite Force HD WatchFace Widget & Live Wallp...
# 53715  53477  Free WiFi Passwords & Internet Hotspot - WiFi ...
# 53731  53733        Relax & Sleep Well: Hypnosis and Meditation
#
#                   genre  rating           reviews cost_label  rate_5_pc  \
# 6                Action     4.3      15,153 total    Install    72.4638
# ...

# %%
appdata.describe()
# Out:
#                  id        rating     rate_5_pc     rate_4_pc     rate_3_pc  \
# count  53732.000000  47688.000000  47688.000000  47688.000000  47688.000000
# mean   26870.528289      4.228942     68.844503     11.903311      5.688799
# std    15516.735617      0.477196     14.547545      6.278470      3.821144
# min        1.000000      1.000000      0.000000      0.000000      0.000000
# 25%    13433.750000      4.000000     61.349700      7.792210      3.174600
# 50%    26866.500000      4.300000     70.422500     11.475400      5.343510
# 75%    40299.250000      4.500000     78.125000     15.528000      7.638890
# max    53751.000000      5.000000    100.000000     86.206900     66.666700
#
#           rate_2_pc     rate_1_pc
# count  47688.000000  47688.000000
# mean       2.927431     10.635961
# std        2.972642     10.422253
# min        0.000000      0.000000
# 25%        0.826446      3.787880
# 50%        2.255640      7.801420
# 75%        3.973510     14.000000
# ...

# %%
appdata.sort_values(["id"],ascending=False)
# Out:
#           id                       app_name             genre  rating  \
# 53658  53751                 Save the Corn!            Casual     NaN
# 53657  53750            Anti Spy Mobile PRO             Tools     4.0
# 53656  53749   Relaxing Music: Sleep Sounds  Health & Fitness     4.6
# 53655  53748    Wind Noise: Relax and Sleep     Music & Audio     4.6
# 53654  53747              Easy Menu Planner      Food & Drink     2.9
# ...      ...                            ...               ...     ...
# 2          5                Sky Fighters 3D            Action     4.2
# 21651      4  Modern Strike Online: PvP FPS            Action     4.2
# 1          3                    Push'em all            Action     3.8
# 0          2    Sonic the Hedgehog™ Classic               NaN     4.1
# 21650      1                     Bowmasters            Action     4.5
#
#                reviews   cost_label  rate_5_pc  rate_4_pc  rate_3_pc  \
# ...

# %%
appdata.shape
# Out:
# (53732, 19)

# %%
pd.set_option("display.max_columns",15)
pd.set_option("display.max_rows",100)

appdata.head(5)
# Out:
#    id                     app_name   genre  rating           reviews  \
# 0   2  Sonic the Hedgehog™ Classic     NaN     4.1     193,898 total
# 1   3                  Push'em all  Action     3.8     119,679 total
# 2   5              Sky Fighters 3D  Action     4.2     196,685 total
# 3   6                  Robbery Bob  Action     4.3     984,779 total
# 4   7               Shadow Fight 2  Action     4.6  12,861,970 total
#
#   cost_label  rate_5_pc  ...  size      installs  current_version  \
# 0    Install    68.0272  ...   61M   10,000,000+            3.5.1
# 1    Install    56.1798  ...   41M   10,000,000+             1.14
# 2    Install    67.1141  ...   19M   10,000,000+              1.5
# 3    Install    74.0741  ...   42M   50,000,000+          1.18.23
# 4    Install    85.4701  ...  142M  100,000,000+            2.5.1
#
#    requires_android content_rating                in_app_products  \
# 0        4.4 and up   Rated for 3+               ₫45,000 per item
# ...

# %%
comments_appdata=pd.read_csv("comment.csv")
comments_appdata
# Out:
#          app_id                                            content  stars  \
# 0             1  The game is fun and fantastic, but the coolest...    3.0
# 1             1  It's an addicting game, the only thing I would...    5.0
# 2             1  I love this game so much that I wanna play thi...    5.0
# 3             1  The game is fun and all, but this problem with...    2.0
# 4             1  I love the gameplay, its really simple. But th...    2.0
# ...         ...                                                ...    ...
# 1468168   53750                                       Good job dev    5.0
# 1468169   53750  It's interesting to find out what apps have th...    3.0
# 1468170   53750  There is not a real option, just uninstall the...    1.0
# 1468171   53750  It's shows hike messenger in the suspicious li...    2.0
# 1468172   53750  Will not finish scan and abruptly closes!!! Ho...    1.0
#
#          helpfuls
# 0           372.0
# 1            37.0
# 2          1164.0
# ...

# %%
appdata.shape
# Out:
# (53732, 19)

# %%
comments_appdata["stars"].value_counts()
# Out:
# 5.0    785911
# 1.0    256030
# 4.0    204932
# 3.0    129532
# 2.0     91743
# Name: stars, dtype: int64

# %%
appdata["rating"].value_counts()
# Out:
# 4.4    5486
# 4.5    5227
# 4.3    4943
# 4.6    4833
# 4.2    4395
# 4.7    3499
# 4.1    3454
# 4.0    2698
# 4.8    2197
# 3.9    2062
# 3.8    1707
# 3.7    1135
# 3.6     908
# 4.9     809
# 3.5     712
# 3.4     604
# 5.0     460
# 3.3     435
# 3.2     402
# 3.1     269
# 3.0     256
# 2.9     196
# 2.8     193
# 2.7     140
# 2.6     129
# 2.5      99
# 2.3      84
# 2.2      78
# 2.4      78
# 2.0      44
# 2.1      40
# 1.8      35
# 1.9      24
# 1.6      19
# 1.7      18
# 1.5       8
# 1.1       3
# 1.2       3
# 1.4       3
# 1.0       2
# 1.3       1
# Name: rating, dtype: int64

# %%
appdata.loc[3]
# Out:
# id                                            6
# app_name                            Robbery Bob
# genre                                    Action
# rating                                      4.3
# reviews                           984,779 total
# cost_label                              Install
# rate_5_pc                               74.0741
# rate_4_pc                               8.14815
# rate_3_pc                               5.18518
# rate_2_pc                               2.96296
# rate_1_pc                               9.62963
# updated                          March 25, 2020
# size                                        42M
# installs                            50,000,000+
# current_version                         1.18.23
# requires_android                     4.1 and up
# content_rating                     Rated for 7+
# in_app_products     ₫18,000 - ₫192,000 per item
# offered_by                       Level Eight AB
# Name: 3, dtype: object

# %%
appdata.loc[[3],["genre","size"]]
# Out:
#     genre size
# 3  Action  42M

# %%
appdata.loc[1:5,"genre":"cost_label"]   #here we used slicing but only differnce in slicing between list and dataframe is 
                                         # this is inclusive of given range of list, so we sliced rows and columns here!
# Out:
#     genre  rating           reviews cost_label
# 1  Action     3.8     119,679 total    Install
# 2  Action     4.2     196,685 total    Install
# 3  Action     4.3     984,779 total    Install
# 4  Action     4.6  12,861,970 total    Install
# 5  Action     4.0      43,322 total    Install

# %% [markdown]
# # Indexing

# %%
appdata.index
# Out:
# RangeIndex(start=0, stop=53732, step=1)

# %%
comments_appdata.loc[1,"content"]
# Out:
# "It's an addicting game, the only thing I would like for them to add is new characters because i've collected all the characters. Another thing I would change is less ads because every time I win/lose a game an ad pops out."

# %%
comments_appdata.set_index("app_id",inplace=True)

# %%
comments_appdata.sort_index(ascending=False)
# Out:
#                                                   content  stars  helpfuls
# app_id
# 53750   Will not finish scan and abruptly closes!!! Ho...    1.0      31.0
# 53750                                    Does It Job! :-)    5.0      12.0
# 53750           developer has excellent customer support.    5.0       9.0
# 53750         This app did not detect my android monitor.    3.0       8.0
# 53750   this app sucks, cant even cancel subscription....    1.0      39.0
# ...                                                   ...    ...       ...
# 1       It was awesome I thought that every single bit...    5.0      34.0
# 1       It's an addicting game, the only thing I would...    5.0      37.0
# 1       This is a very entertaining game. You graduall...    4.0      61.0
# 1       I want playgendary to add something in the nex...    5.0       7.0
# 1       The game is fun and fantastic, but the coolest...    3.0     372.0
#
# [1468173 rows x 3 columns]

# %% [markdown]
# # Filtering Data

# %%
appdata
# Out:
#           id                                           app_name  \
# 0          2                        Sonic the Hedgehog™ Classic
# 1          3                                        Push'em all
# 2          5                                    Sky Fighters 3D
# 3          6                                        Robbery Bob
# 4          7                                     Shadow Fight 2
# ...      ...                                                ...
# 53727  53653  Omni Websites: Free Website Builder & Online S...
# 53728  53680                           Web Alert Expansion Pack
# 53729  53683  Reading Comprehension – GRE® Test Prep & Practice
# 53730  53707                     Soulspace Christian Meditation
# 53731  53733        Relax & Sleep Well: Hypnosis and Meditation
#
#                   genre  rating           reviews   cost_label  rate_5_pc  \
# 0                   NaN     4.1     193,898 total      Install    68.0272
# ...

# %%
rate= appdata["rating"]>4.5

# %%
appdata.loc[rate,["app_name","rating","size","content_rating"]]
# Out:
#                                                 app_name  rating  \
# 4                                         Shadow Fight 2     4.6
# 11                                          Swamp Attack     4.6
# 22                  Sniper Strike – FPS 3D Shooting Game     4.7
# 47                                           Crossy Road     4.6
# 54     No.Pix - Color by Number, Pixel Art Coloring Book     4.7
# ...                                                  ...     ...
# 53710                                 My Fitness Trainer     4.6
# 53722     iSticker - Sticker Maker & Meme Creator for WA     4.8
# 53723                                     Sound Analyzer     4.7
# 53730                     Soulspace Christian Meditation     4.8
# 53731        Relax & Sleep Well: Hypnosis and Meditation     4.7
#
#                      size content_rating
# 4                    142M  Rated for 12+
# 11                    70M   Rated for 7+
# 22                    92M  Rated for 18+
# ...

# %%
companies=["VOODOO","SEGA","NEKKI"]
offeredby=appdata['offered_by'].isin(companies)     #isin() is a method to check weather a rqd value is present or not
appdata.loc[offeredby]
# Out:
#           id                           app_name         genre  rating  \
# 0          2        Sonic the Hedgehog™ Classic           NaN     4.1
# 1          3                        Push'em all        Action     3.8
# 4          7                     Shadow Fight 2        Action     4.6
# 19        22                        aquapark.io        Action     4.1
# 29        33                       Knock'em All        Action     4.2
# 64        69                         Sonic Dash           NaN     4.6
# 74        80                       Sonic Forces           NaN     4.4
# 140      149           Sonic Dash 2: Sonic Boom           NaN     4.2
# 147      157    Sonic The Hedgehog 4 Episode II           NaN     4.1
# 150      160                        Woodturning    Simulation     3.6
# 151      161                            Hole.io        Arcade     4.3
# 154      164                         Crowd City        Arcade     4.3
# ...

# %% [markdown]
# # Updating Rows and Columns

# %%
 appdata.rename(columns={'current_version':'latest_version'},inplace=True)

# %%
appdata
# Out:
#           id                                           app_name  \
# 0          2                        Sonic the Hedgehog™ Classic
# 1          3                                        Push'em all
# 2          5                                    Sky Fighters 3D
# 3          6                                        Robbery Bob
# 4          7                                     Shadow Fight 2
# ...      ...                                                ...
# 53727  53653  Omni Websites: Free Website Builder & Online S...
# 53728  53680                           Web Alert Expansion Pack
# 53729  53683  Reading Comprehension – GRE® Test Prep & Practice
# 53730  53707                     Soulspace Christian Meditation
# 53731  53733        Relax & Sleep Well: Hypnosis and Meditation
#
#                   genre  rating           reviews   cost_label  rate_5_pc  \
# 0                   NaN     4.1     193,898 total      Install    68.0272
# ...

# %%
appdata['genre'].replace({'Health & Fitness':"Health"}) #we cannot use map() here because it changes other values in data as NaN
# Out:
# 0                 NaN
# 1              Action
# 2              Action
# 3              Action
# 4              Action
#              ...
# 53727    Productivity
# 53728    Productivity
# 53729       Education
# 53730          Health
# 53731          Health
# Name: genre, Length: 53732, dtype: object

# %% [markdown]
# # Sorting

# %%
appdata.sort_values(by=['offered_by','rating'],ascending=[False,True],inplace=True)

# %%
appdata[['offered_by','rating']].head(100)
# Out:
#                                      offered_by  rating
# 21002                                 🥇Alot.pro     4.0
# 21001                                 🥇Alot.pro     4.6
# 10176                                 🤖 Bite AI     4.3
# 23306  🚴‍♂️🏃‍♀️ BIPR Cycling, Running & Fitness     3.8
# 23303  🚴‍♂️🏃‍♀️ BIPR Cycling, Running & Fitness     NaN
# 21662                   😍 رایگان و بدون اینترنت     4.8
# 1670                    😍 رایگان و بدون اینترنت     4.9
# 42939                          📱 BadApps Studio     4.2
# 27426                          📱 BadApps Studio     4.4
# 49698                         📖 Your Smart Apps     4.7
# 48028                         📈 HitBTC Exchange     NaN
# 41792                                   💪APLabs     4.6
# 18591                     💎 LevelUp Brain games     4.5
# 17858                        💎 Daedalus Games 💎     4.0
# 6790                         💎 Daedalus Games 💎     4.2
# 33160                            🐮 Gooble Games     4.7
# ...

# %%
# appdata['rate_5_pc'].nlargest(100)       #nlargest(),nsmallest() used to see values of highest and smallest 
appdata['rate_5_pc'].nsmallest(100)
# Out:
# 49180     0.00000
# 49509     0.00000
# 49701     0.00000
# 27810     0.00000
# 48750     0.00000
# 22712     0.00000
# 163       0.00000
# 50565     0.00000
# 45613     0.00000
# 21608     0.00000
# 36062     0.00000
# 36008     0.00000
# 23580     0.00000
# 30174     0.00000
# 21155     0.00000
# 48281     0.00000
# 43393     0.00000
# 39828     0.00000
# 50605     0.00000
# 48648     0.00000
# 3908      1.45985
# 48880     1.87500
# 49103     3.40136
# 18642     3.57143
# 21553     4.34783
# 2896      4.42478
# 23875     4.54545
# 3506      4.76190
# 23406     5.14706
# 48169     5.18518
# 49958     5.18518
# 46054     5.34351
# 10849     5.83333
# 27411     6.49351
# 46393     6.77966
# 29193     6.77966
# 27273     6.91824
# 48690     7.09677
# 44370     7.43802
# 27251     7.63889
# 14514     7.63889
# 22715     7.85714
# 2776      7.85714
# 50044     8.45070
# 23041     8.82353
# 41342     8.97436
# 42534     9.01639
# 53148     9.04762
# 48741     9.09091
# 49985     9.09091
# ...

# %%
 appdata.nsmallest(100,'rate_5_pc')    #here we can see whole dataframe using same method
# Out:
#           id                                          app_name  \
# 49180  49680           Real Terrain 3D Modeling To STL,OBJ,DXF
# 49509  50029                         SCMP Newspaper Redemption
# 49701  50233                                     Relay Control
# 27810  28383            OCBC Wing Hang Business Mobile Banking
# 48750  49224                                  Schwinn™ Toolbox
# 22712  22968                                           LElight
# 163      173                                              LVD8
# 50565  51153             Calorie Pal - Free Calorie Calculator
# 45613  47289                                        Project EV
# 21608  22856                                    Solis TechView
# 36062  37143        FX Video Converter - video trim and cutter
# 36008  37084                               Exact Field Service
# 23580  23887                                       Scoliometer
# 30174  30896                                        EG Voyager
# ...

# %% [markdown]
# # Grouping and Aggerating

# %%
appdata['rating'].median()
# Out:
# 4.3

# %%
appdata['rating'].mode()
# Out:
# 0    4.4
# dtype: float64

# %%
appdata['rating'].mean()      #mean is effected by the outliers ,so it is good to use median
# Out:
# 4.228942291561871

# %%
appdata['rating'].describe()
# Out:
# count    47688.000000
# mean         4.228942
# std          0.477196
# min          1.000000
# 25%          4.000000
# 50%          4.300000
# 75%          4.500000
# max          5.000000
# Name: rating, dtype: float64

# %%
appdata.median()
# Out:
# id           26866.50000
# rating           4.30000
# rate_5_pc       70.42250
# rate_4_pc       11.47540
# rate_3_pc        5.34351
# rate_2_pc        2.25564
# rate_1_pc        7.80142
# dtype: float64

# %%
appdata.describe()
# Out:
#                  id        rating     rate_5_pc     rate_4_pc     rate_3_pc  \
# count  53732.000000  47688.000000  47688.000000  47688.000000  47688.000000
# mean   26870.528289      4.228942     68.844503     11.903311      5.688799
# std    15516.735617      0.477196     14.547545      6.278470      3.821144
# min        1.000000      1.000000      0.000000      0.000000      0.000000
# 25%    13433.750000      4.000000     61.349700      7.792210      3.174600
# 50%    26866.500000      4.300000     70.422500     11.475400      5.343510
# 75%    40299.250000      4.500000     78.125000     15.528000      7.638890
# max    53751.000000      5.000000    100.000000     86.206900     66.666700
#
#           rate_2_pc     rate_1_pc
# count  47688.000000  47688.000000
# mean       2.927431     10.635961
# std        2.972642     10.422253
# min        0.000000      0.000000
# 25%        0.826446      3.787880
# 50%        2.255640      7.801420
# 75%        3.973510     14.000000
# ...

# %%
appdata['rating'].count()     #above and here count is the no of of rows which are not NaN
# Out:
# 47688

# %%
appdata['rating'].value_counts()
# Out:
# 4.4    5486
# 4.5    5227
# 4.3    4943
# 4.6    4833
# 4.2    4395
# 4.7    3499
# 4.1    3454
# 4.0    2698
# 4.8    2197
# 3.9    2062
# 3.8    1707
# 3.7    1135
# 3.6     908
# 4.9     809
# 3.5     712
# 3.4     604
# 5.0     460
# 3.3     435
# 3.2     402
# 3.1     269
# 3.0     256
# 2.9     196
# 2.8     193
# 2.7     140
# 2.6     129
# 2.5      99
# 2.3      84
# 2.4      78
# 2.2      78
# 2.0      44
# 2.1      40
# 1.8      35
# 1.9      24
# 1.6      19
# 1.7      18
# 1.5       8
# 1.4       3
# 1.2       3
# 1.1       3
# 1.0       2
# 1.3       1
# Name: rating, dtype: int64

# %%
appdata['rating'].value_counts(normalize=True) #this normalise will give the result in percentage
# Out:
# 4.4    0.115039
# 4.5    0.109608
# 4.3    0.103653
# 4.6    0.101346
# 4.2    0.092162
# 4.7    0.073373
# 4.1    0.072429
# 4.0    0.056576
# 4.8    0.046070
# 3.9    0.043239
# 3.8    0.035795
# 3.7    0.023801
# 3.6    0.019040
# 4.9    0.016964
# 3.5    0.014930
# 3.4    0.012666
# 5.0    0.009646
# 3.3    0.009122
# 3.2    0.008430
# 3.1    0.005641
# 3.0    0.005368
# 2.9    0.004110
# 2.8    0.004047
# 2.7    0.002936
# 2.6    0.002705
# 2.5    0.002076
# 2.3    0.001761
# 2.4    0.001636
# 2.2    0.001636
# 2.0    0.000923
# 2.1    0.000839
# 1.8    0.000734
# 1.9    0.000503
# 1.6    0.000398
# 1.7    0.000377
# 1.5    0.000168
# 1.4    0.000063
# 1.2    0.000063
# 1.1    0.000063
# 1.0    0.000042
# 1.3    0.000021
# Name: rating, dtype: float64

# %%
appdata['offered_by'].value_counts()
# Out:
# BabyBus             116
# Amino Apps          105
# mobirix              94
# Tapps Games          75
# Hippo Kids Games     69
#                    ...
# Poparide              1
# Tools4Monitoring      1
# Kaloey                1
# PayWay                1
# Acintyo, Inc.         1
# Name: offered_by, Length: 20412, dtype: int64

# %%
appdata.groupby(['offered_by'])

# %%
company_grp=appdata.groupby(['offered_by'])  #here we created a groupby and it forms series of on basis of offered_by

# %%
company_grp.get_group('BabyBus')     #this gives all the dataframe consist of only where offered_by is BabyBus4,.hg
# Out:
#           id                                   app_name genre  rating  \
# 1081    1142  Baby Panda’s Potty Training - Toilet Time   NaN     3.7
# 1088    1150                    Baby Panda's Daily Life   NaN     3.9
# 4559    4809             Heavy Machines - Free for kids   NaN     3.9
# 4676    4934                     Baby Panda's Bath Time   NaN     3.9
# 4681    4940              The Magic Words - Polite Baby   NaN     3.9
# ...      ...                                        ...   ...     ...
# 13815  14618                      Baby Panda Organizing   NaN     4.4
# 32421  33280               Baby Panda: Care for animals   NaN     4.4
# 32432  33291              Baby Panda’s Chinese Holidays   NaN     4.4
# 33051  33947                   Baby Panda’s First Words   NaN     4.4
# 4492    4738     Little Panda's Ice and Snow Wonderland   NaN     4.6
#
#             reviews cost_label  rate_5_pc  ...  size     installs  \
# ...

# %%
company_grp.get_group('NEKKI')    #get_group is used to return the group of mentioned offered_by value
# Out:
#        id                        app_name         genre  rating  \
# 950  1006      11x11: Soccer Club Manager        Sports     3.6
# 948  1004                Vector 2 Premium        Arcade     3.7
# 222   235                  Shadow Fight 3  Role Playing     4.0
# 949  1005                     Vector Full        Arcade     4.0
# 951  1007                         Lintrix        Puzzle     4.0
# 954  1010                        Vector 2        Arcade     4.3
# 221   234                          Vector        Arcade     4.4
# 946  1002  Shadow Fight 2 Special Edition        Action     4.5
# 4       7                  Shadow Fight 2        Action     4.6
#
#               reviews    cost_label  rate_5_pc  ...  size      installs  \
# 950      25,411 total       Install    52.3560  ...  109M    1,000,000+
# 948         787 total   ₫49,000 Buy    53.4759  ...   96M       10,000+
# 222   2,528,316 total       Install    62.8931  ...  108M   50,000,000+
# ...

# %%
filt=appdata['offered_by']=='SEGA'         #the above code does the same thing of group by 
appdata.loc[filt]
# Out:
#           id                           app_name         genre  rating  \
# 2272    2394             FMdB - Soccer Database        Sports     2.3
# 2278    2400        Football Manager 2020 Touch    Simulation     3.0
# 7597    8034  Super Monkey Ball: Sakura Edition        Arcade     3.5
# 405      427            Virtua Tennis Challenge        Sports     3.6
# 42113  43585           Space Harrier II Classic        Arcade     3.7
# 2286    2408                     Sonic Jump Pro        Arcade     3.8
# 2289    2411     The Revenge of Shinobi Classic        Action     4.0
# 19382  20501               Decap Attack Classic        Arcade     4.0
# 19388  20508               Beyond Oasis Classic  Role Playing     4.0
# 0          2        Sonic the Hedgehog™ Classic           NaN     4.1
# 147      157    Sonic The Hedgehog 4 Episode II           NaN     4.1
# 2275    2397                 Sonic 4™ Episode I        Arcade     4.1
# ...

# %%
filt=appdata['offered_by']=='SEGA'         #Here we can see for SAGA the no. of people rated and comparing to what they rated
appdata.loc[filt]['rating'].value_counts()
# Out:
# 4.1    9
# 4.3    7
# 4.2    3
# 4.0    3
# 4.4    2
# 4.6    1
# 3.8    1
# 3.7    1
# 2.3    1
# 3.6    1
# 3.5    1
# 3.0    1
# Name: rating, dtype: int64

# %%
filt=appdata['offered_by']=='NEKKI'         #Here we can see for NEKKI the no. of people rated and comparing to what they rated
appdata.loc[filt]['rating'].value_counts()    #value counts() give count of the given condition
# Out:
# 4.0    3
# 3.6    1
# 4.3    1
# 3.7    1
# 4.6    1
# 4.5    1
# 4.4    1
# Name: rating, dtype: int64

# %%
company_grp['rating'].value_counts().head(100)
                                            #here we can clearly see the most people ratings for every company or offered_by
# Out:
# offered_by                                     rating
# #LearnSmart                                    4.6       1
# $@pp Labs                                      3.6       1
#                                                4.0       1
# ((RayDar)) Connected                           4.4       1
# (Andrei & Aleksandr Krupiankou)                3.7       1
#                                                4.2       1
#                                                4.4       1
#                                                4.5       1
# +HOME by Ateam                                 4.6       1
#                                                4.7       1
# ,MTjin                                         4.2       1
# -Aman-                                         4.6       2
#                                                3.9       1
# .kk                                            4.4       1
# 0.1%                                           4.2       1
# ...

# %%
company_grp['rating'].value_counts(normalize=True).loc['SEGA']  #we use normalize=True to get the percentage of the no. of ratings given
# Out:
# rating
# 4.1    0.290323
# 4.3    0.225806
# 4.0    0.096774
# 4.2    0.096774
# 4.4    0.064516
# 2.3    0.032258
# 3.0    0.032258
# 3.5    0.032258
# 3.6    0.032258
# 3.7    0.032258
# 3.8    0.032258
# 4.6    0.032258
# Name: rating, dtype: float64

# %%
company_grp['rating'].median().loc['SEGA']
# Out:
# 4.1

# %%
company_grp['rating'].agg(['median','mean'])      #to get multiple stats we use agg([]) and pass a list in it
# Out:
#                                           median  mean
# offered_by
# #LearnSmart                                 4.60  4.60
# $@pp Labs                                   3.80  3.80
# ((RayDar)) Connected                        4.40  4.40
# (Andrei & Aleksandr Krupiankou)             4.30  4.20
# (주)클루소프트                                     NaN   NaN
# ...                                          ...   ...
# 📱 BadApps Studio                            4.30  4.30
# 😍 رایگان و بدون اینترنت                     4.85  4.85
# 🚴‍♂️🏃‍♀️ BIPR Cycling, Running & Fitness    3.80  3.80
# 🤖 Bite AI                                   4.30  4.30
# 🥇Alot.pro                                   4.30  4.30
#
# [20412 rows x 2 columns]

# %%
company_grp['rating'].agg(['median','mean']).loc['NEKKI']       #agg() will let us do stats on multiple
# Out:
# median    4.000000
# mean      4.122222
# Name: NEKKI, dtype: float64

# %%
filt=appdata['offered_by']=='NEKKI'          #here we filtered where offeredby NEKKI and where content is 18+
appdata.loc[filt]['content_rating'].str.contains('Rated for 18+')               #we get locations where the above cond. is met
# Out:
# 950    False
# 948    False
# 222    False
# 949    False
# 951    False
# 954    False
# 221    False
# 946    False
# 4      False
# Name: content_rating, dtype: bool

# %%
filt=appdata['offered_by']=='SEGA'                 
appdata.loc[filt]['genre']        #we get the genres of the app offered by SEGA
# Out:
# 2272           Sports
# 2278       Simulation
# 7597           Arcade
# 405            Sports
# 42113          Arcade
# 2286           Arcade
# 2289           Action
# 19382          Arcade
# 19388    Role Playing
# 0                 NaN
# 147               NaN
# 2275           Arcade
# 2287           Action
# 2296           Action
# 7235           Action
# 7631        Adventure
# 7633           Action
# 7634           Action
# 140               NaN
# 400            Sports
# 42112    Role Playing
# 401            Action
# 404            Action
# 2292           Arcade
# 4113           Action
# 19385    Role Playing
# 21658             NaN
# 21783          Action
# 74                NaN
# 6881              NaN
# 64                NaN
# Name: genre, dtype: object

# %%
filt=appdata['offered_by']=='SEGA'          #here had no. of apps which have genre as Action and offered by SEGA
appdata.loc[filt]['genre'].str.contains('Action').sum()
# Out:
# 10

# %%
company_grp['offered_by'].str.contains('SEGA').sum()     #error bcoz  company_grp is series and doesnt have str attribute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-4c5af2cbbfca> in <module>
# ----> 1 company_grp['offered_by'].str.contains('SEGA').sum()     #error bcoz  company_grp is series and doesnt have str attribute
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578             return self[attr]
#     579
# --> 580         raise AttributeError(
#     581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
company_grp['offered_by'].apply(lambda x:x.str.contains('SEGA').sum())
# Out:
# offered_by
# #LearnSmart                                 0
# $@pp Labs                                   0
# ((RayDar)) Connected                        0
# (Andrei & Aleksandr Krupiankou)             0
# (주)클루소프트                                    0
#                                            ..
# 📱 BadApps Studio                            0
# 😍 رایگان و بدون اینترنت                     0
# 🚴‍♂️🏃‍♀️ BIPR Cycling, Running & Fitness    0
# 🤖 Bite AI                                   0
# 🥇Alot.pro                                   0
# Name: offered_by, Length: 20412, dtype: int64

# %%
company_apps=appdata['offered_by'].value_counts()
company_apps
# Out:
# BabyBus             116
# Amino Apps          105
# mobirix              94
# Tapps Games          75
# Hippo Kids Games     69
#                    ...
# Poparide              1
# Tools4Monitoring      1
# Kaloey                1
# PayWay                1
# Acintyo, Inc.         1
# Name: offered_by, Length: 20412, dtype: int64

# %%
company_grp['rating'].value_counts().
# Out:
#   File "<ipython-input-76-4afa188badc3>", line 1
#     company_grp['rating'].value_counts().
#                                          ^
# SyntaxError: invalid syntax

# %%
ratings=appdata.loc[appdata['rating']==4.5]
ratings
# Out:
#           id                                           app_name  \
# 18591  19665                  Synapptico - Brain training games
# 40819  42191       Nuttri - Baby Food: Guide to starting solids
# 34125  35086  Quake & Volcanoes: 3D Globe of Volcanic Eruptions
# 22467  14839     Retrogram 🌴: Retrowave Photo, GIF & Text Maker
# 29148  29810                                 허밍순 - 영어 공부의 모든 기술
# ...      ...                                                ...
# 6745    7137                                  Tiên Ma Truyền Kỳ
# 12838  13578                     Music Player & HD Video Player
# 14545  15393                 Ruler - Bubble Level - Angle Meter
# 14820  15681                  Browser - Smart and Fast Explorer
# 6106    6452   Multiplication table - learn easily, mathematics
#
#                genre  rating      reviews cost_label  rate_5_pc  ...  size  \
# 18591            NaN     4.5    335 total    Install    68.4931  ...   16M
# ...

# %%
company_grp['offered_by'].apply(lambda x:x.str.contains('NEKKI'))
# Out:
# 21002    False
# 21001    False
# 10176    False
# 23306    False
# 23303    False
#          ...
# 47401      NaN
# 48084      NaN
# 49654      NaN
# 51906      NaN
# 53653      NaN
# Name: offered_by, Length: 53732, dtype: object

# %%
appdata.loc[(appdata['rating']==4.3) & (appdata['offered_by']=='SEGA')]  #here we filterd the rating and offered_by
# Out:
#           id                      app_name         genre  rating  \
# 401      423              Sonic CD Classic        Action     4.3
# 404      426     Streets of Rage 2 Classic        Action     4.3
# 2292    2414           Golden Axe Classics        Arcade     4.3
# 4113    4335            Comix Zone Classic        Action     4.3
# 19385  20505        Shining Force Classics  Role Playing     4.3
# 21658    153  Sonic The Hedgehog 2 Classic           NaN     4.3
# 21783   2420       Streets of Rage Classic        Action     4.3
#
#              reviews cost_label  rate_5_pc  ...  size     installs  \
# 401     56,592 total    Install    70.9220  ...   24M   5,000,000+
# 404     15,679 total    Install    68.4931  ...   58M   1,000,000+
# 2292    14,345 total    Install    67.1141  ...   70M   1,000,000+
# 4113    27,665 total    Install    70.4225  ...   59M   1,000,000+
# 19385    6,366 total    Install    67.5676  ...   70M     100,000+
# ...

# %%
apps_rated=appdata.loc[(appdata['rating']==4.3) & (appdata['offered_by'])]  #here we filterd the all 4.3 rated apps from all the offered_by companies
apps_rated
# Out:
#           id                                          app_name  \
# 10176  10769  Bitesnap: Photo Food Tracker and Calorie Counter
# 41248  42666      Smart Kalimba - Kalimba tuning, playing mode
# 36400  37500                          Infinite Hero : Idle RPG
# 3781    3986                                  북플 bookple - 독보적
# 29722  30415                                        stylenanda
# ...      ...                                               ...
# 46349  27460                                     IONOS HiDrive
# 5320    5616   HD Filter Camera - Perfect Photo & Video Camera
# 14813  15673       1 Launcher - Best and Smart Home Screen App
# 22444  14403                                    Leoncito Alado
# 52163  52848                                         Oppa doll
#
#                   genre  rating        reviews cost_label  rate_5_pc  ...  \
# 10176  Health & Fitness     4.3      174 total    Install    68.9655  ...
# ...

# %%
filt_apps=pd.concat([ratings,apps_rated],axis='columns',sort=False)
filt_apps.head(50)
# Out:
#         id                                           app_name         genre  \
# 3      NaN                                                NaN           NaN
# 6      NaN                                                NaN           NaN
# 8     11.0     Sniper 3D: Fun Offline Gun Shooting Games Free        Action
# 14     NaN                                                NaN           NaN
# 17     NaN                                                NaN           NaN
# 18     NaN                                                NaN           NaN
# 23     NaN                                                NaN           NaN
# 25     NaN                                                NaN           NaN
# 27    31.0                                     Javelin Master        Action
# 28    32.0        Modern Ops - Online FPS (Gun Games Shooter)        Action
# 37     NaN                                                NaN           NaN
# ...

# %% [markdown]
# # Cleaning Data

# %%
appdata.dtypes
# Out:
# id                    int64
# app_name             object
# genre                object
# rating              float64
# reviews              object
# cost_label           object
# rate_5_pc           float64
# rate_4_pc           float64
# rate_3_pc           float64
# rate_2_pc           float64
# rate_1_pc           float64
# updated              object
# size                 object
# installs             object
# latest_version       object
# requires_android     object
# content_rating       object
# in_app_products      object
# offered_by           object
# dtype: object

# %%
appdata['content_rating'].unique()  #unique() method will tell all the unique values present in the column
                                    #we can see here a diff. datatype as unrated so we can change these kinda value
# Out:
# array(['Rated for 3+', 'Rated for 12+', 'Rated for 18+', 'Rated for 7+',
#        'Rated for 16+', 'Unrated', nan], dtype=object)

# %%
#we can clean data if needed my changing the datatypes of rows and columns 
#we can also replace the specific values by replace() method and do many filters and cleaning
