# %%
import pandas as pd

# %%
# bitcdata=pd.read_csv("BTC-INR.csv")
# bitcdata.head(10)

# %%
# date_par=lambda x:pd.datetime.strptime(x,'%Y-%m-%d %I-%p')   #used to convert to datetime directly while loading data
# bitcdata=pd.read_csv("ETH_1h.csv",parse_dates=['Date'],date_parser=date_par)
bithdata=pd.read_csv('ETH_1h.csv')
bithdata
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
# bithdata['Date'][1]      
#or
bithdata.loc[1,'Date']
# Out:
# '2020-03-13 07-PM'

# %%
# bithdata['Date'][1].day_name()     #it is an error because to work it has to be datetime datatype not str

# %%
bithdata['Date']=pd.to_datetime(bithdata['Date'],format='%Y-%m-%d %I-%p')
bithdata['Date']                        #we use format according to the data available to us and format it with its codes
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
bithdata['Date'][50].day_name()
# Out:
# 'Wednesday'

# %%
bithdata['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
bithdata['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
bithdata['Day_name']=bithdata['Date'].dt.day_name()

# %%
bithdata
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#        Day_name
# ...

# %%
bithdata['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
bithdata['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
bithdata['Date'].max()-bithdata['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
bithdata.loc[(bithdata['Date']>='2019')& (bithdata['Date']<'2020')]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       Day_name
# 1749   Tuesday
# ...

# %%
bithdata.set_index('Date',inplace=True)  #here we set the index as the Date using set_index()

# %%
bithdata['2020']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                       Day_name
# Date
# 2020-03-13 20:00:00     Friday
# ...

# %%
bithdata['2020-2':'2020-3'] #we can also slice the data
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2020-02-01 04:00:00  ETHUSD  183.16  183.49  181.34  181.74   706490.86
# 2020-02-01 03:00:00  ETHUSD  183.61  183.81  182.41  183.16   279177.55
# 2020-02-01 02:00:00  ETHUSD  183.59  184.00  181.93  183.61  1829192.09
# 2020-02-01 01:00:00  ETHUSD  181.06  183.64  180.98  183.59   946295.21
# 2020-02-01 00:00:00  ETHUSD  179.74  181.41  179.00  181.06   637332.52
#
#                      Day_name
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
bithdata['2020-2':'2020-3']['High'].mean()
# Out:
# 230.97131343283587

# %%
bithdata['2020-3-3']['High'].max()
# Out:
# 232.92

# %%
bithdata['2020-3-3']['High'].min()
# Out:
# 223.42

# %%
highs_by_m=bithdata['High'].resample('M').max()
highs_by_m                                        #resample() here created a dataframe with given cond.
# Out:
# Date
# 2017-07-31     293.73
# 2017-08-31     392.00
# 2017-09-30     396.88
# 2017-10-31     350.00
# 2017-11-30     518.13
# 2017-12-31     875.00
# 2018-01-31    1419.96
# 2018-02-28    1143.00
# 2018-03-31     878.00
# 2018-04-30     711.00
# 2018-05-31     828.97
# 2018-06-30     627.83
# 2018-07-31     515.88
# 2018-08-31     435.48
# 2018-09-30     302.20
# 2018-10-31     234.92
# 2018-11-30     222.78
# 2018-12-31     159.51
# 2019-01-31     160.61
# 2019-02-28     165.62
# 2019-03-31     147.00
# 2019-04-30     187.62
# 2019-05-31     288.77
# 2019-06-30     364.49
# 2019-07-31     318.60
# 2019-08-31     239.45
# 2019-09-30     224.71
# 2019-10-31     199.50
# 2019-11-30     194.60
# 2019-12-31     153.00
# 2020-01-31     186.89
# 2020-02-29     290.00
# 2020-03-31     253.01
# Freq: M, Name: High, dtype: float64

# %%
# %matplotlib inline

# %%
highs_by_m.plot(color='g')

# %%
bithdata.resample('M').agg({'High':'max','Low':'min','Close':'mean','Volume':'sum'})
# Out:
#                High     Low        Close        Volume
# Date
# 2017-07-31   293.73  130.26   220.010969  1.818282e+09
# 2017-08-31   392.00  200.82   298.511815  1.529929e+09
# 2017-09-30   396.88  202.25   298.524639  1.678947e+09
# 2017-10-31   350.00  275.46   305.649772  8.155377e+08
# 2017-11-30   518.13  278.88   355.646292  1.974056e+09
# 2017-12-31   875.00  415.01   629.898011  5.172910e+09
# 2018-01-31  1419.96  727.14  1084.040390  7.728885e+09
# 2018-02-28  1143.00  555.56   872.098304  4.123206e+09
# 2018-03-31   878.00  365.00   629.704341  2.028503e+09
# 2018-04-30   711.00  360.00   516.082944  1.899357e+09
# 2018-05-31   828.97  507.00   676.327298  2.241083e+09
# 2018-06-30   627.83  404.22   519.794347  1.254270e+09
# 2018-07-31   515.88  418.23   461.838898  7.496308e+08
# 2018-08-31   435.48  250.28   323.016788  9.676426e+08
# 2018-09-30   302.20  167.00   226.846583  1.006817e+09
# 2018-10-31   234.92  185.06   207.737043  4.391482e+08
# ...
