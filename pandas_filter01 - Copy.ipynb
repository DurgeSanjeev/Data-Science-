# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pokemon_data01= pd.read_csv("pokemon_data.csv")
pokemon_data01
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
newdf=pokemon_data01.loc[(pokemon_data01["Type 1"]=="Rock") & (pokemon_data01["Type 2"]=="Grass")]
newdf.to_csv("newone.csv")
# newdf=newdf.reset_index()  #we reset index to new in sequence
newdf.reset_index(inplace=True)     #instead of assigning it we can use inplace="True"
newdf
# Out:
#    index    #     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    377  345   Lileep   Rock  Grass  66      41       77       61       87
# 1    378  346  Cradily   Rock  Grass  86      81       97       81      107
#
#    Speed  Generation  Legendary
# 0     23           3      False
# 1     43           3      False

# %%
pokemon_data01.loc[~pokemon_data01["Name"].str.contains("Mega")]  # we removed mega naming values from table with usnig 
                                                #str.contains("name")  and using tild symbol(~) saying not instead of "!"
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
import re
pokemon_data01.loc[pokemon_data01["Type 1"].str.contains("Dragon|Ground",regex=True)]
pokemon_data01.loc[pokemon_data01["Type 1"].str.contains("dragon|ground",flags=re.I,regex=True)]
# Out:
#        #                Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 32    27           Sandshrew  Ground     NaN   50      75       85       20
# 33    28           Sandslash  Ground     NaN   75     100      110       45
# 55    50             Diglett  Ground     NaN   10      55       25       35
# 56    51             Dugtrio  Ground     NaN   35      80       50       50
# 112  104              Cubone  Ground     NaN   50      50       95       40
# ..   ...                 ...     ...     ...  ...     ...      ...      ...
# 712  646  KyuremWhite Kyurem  Dragon     Ice  125     120       90      170
# 774  704               Goomy  Dragon     NaN   45      50       35       55
# 775  705             Sliggoo  Dragon     NaN   68      75       53       83
# 776  706              Goodra  Dragon     NaN   90     100       70      110
# 794  718    Zygarde50% Forme  Dragon  Ground  108     100      121       81
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
 pokemon_data01.loc[pokemon_data01["Name"].str.contains("^du[a-z]*",flags=re.I,regex=True)]
# Out:
#        #       Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 56    51    Dugtrio   Ground     NaN   35      80       50       50       70
# 221  206  Dunsparce   Normal     NaN  100      70       70       65       65
# 292  269     Dustox      Bug  Poison   60      50       70       50       90
# 388  355    Duskull    Ghost     NaN   20      40       90       30       90
# 389  356   Dusclops    Ghost     NaN   40      70      130       60      130
# 529  477   Dusknoir    Ghost     NaN   45     100      135       65      135
# 639  578    Duosion  Psychic     NaN   65      40       50      125       60
# 641  580   Ducklett    Water  Flying   62      44       50       44       50
# 693  632     Durant      Bug   Steel   58     109      112       48       48
#
#      Speed  Generation  Legendary
# 56     120           1      False
# 221     45           2      False
# 292     65           3      False
# 388     25           3      False
# ...

# %%
pokemon_data01.loc[pokemon_data01["Type 1"]=="Ground","Type 1"]="Earth"   #changed all values named as Ground
pokemon_data01.loc[(pokemon_data01["Type 1"]=="Earth")]
pokemon_data01.loc[pokemon_data01["Type 1"]=="Earth","Type 1"]="Ground"
pokemon_data01.loc[(pokemon_data01["Type 1"]=="Ground")]
# Out:
#        #                     Name  Type 1    Type 2   HP  Attack  Defense  \
# 32    27                Sandshrew  Ground       NaN   50      75       85
# 33    28                Sandslash  Ground       NaN   75     100      110
# 55    50                  Diglett  Ground       NaN   10      55       25
# 56    51                  Dugtrio  Ground       NaN   35      80       50
# 112  104                   Cubone  Ground       NaN   50      50       95
# 113  105                  Marowak  Ground       NaN   60      80      110
# 119  111                  Rhyhorn  Ground      Rock   80      85       95
# 120  112                   Rhydon  Ground      Rock  105     130      120
# 222  207                   Gligar  Ground    Flying   65      75      105
# 250  231                   Phanpy  Ground       NaN   90      60       60
# 251  232                  Donphan  Ground       NaN   90     120      120
# 359  328                 Trapinch  Ground       NaN   45     100       45
# ...

# %%
pokemon_data01.loc[pokemon_data01["Type 1"]=="Ground","Legendry"]=True
pokemon_data01.loc[(pokemon_data01["Type 1"]=="Ground")]
# Out:
#        #                     Name  Type 1    Type 2   HP  Attack  Defense  \
# 32    27                Sandshrew  Ground       NaN   50      75       85
# 33    28                Sandslash  Ground       NaN   75     100      110
# 55    50                  Diglett  Ground       NaN   10      55       25
# 56    51                  Dugtrio  Ground       NaN   35      80       50
# 112  104                   Cubone  Ground       NaN   50      50       95
# 113  105                  Marowak  Ground       NaN   60      80      110
# 119  111                  Rhyhorn  Ground      Rock   80      85       95
# 120  112                   Rhydon  Ground      Rock  105     130      120
# 222  207                   Gligar  Ground    Flying   65      75      105
# 250  231                   Phanpy  Ground       NaN   90      60       60
# 251  232                  Donphan  Ground       NaN   90     120      120
# 359  328                 Trapinch  Ground       NaN   45     100       45
# ...

# %%
pokemon_data01=pd.read_csv("modified01.csv")

# %%
pokemon_data01.loc[pokemon_data01["Attack"]>100,["Legendary","Legendary.1"]]=["Great","Best"]
pokemon_data01.loc[(pokemon_data01["Legendary.1"]=="Best")]
# Out:
#      Unnamed: 0 Legendary    #                       Name   Type 1  Type 2  \
# 7             7     Great    6  CharizardMega Charizard X     Fire  Dragon
# 8             8     Great    6  CharizardMega Charizard Y     Fire  Flying
# 12           12     Great    9    BlastoiseMega Blastoise    Water     NaN
# 19           19     Great   15      BeedrillMega Beedrill      Bug  Poison
# 39           39     Great   34                   Nidoking   Poison  Ground
# ..          ...       ...  ...                        ...      ...     ...
# 793         793     Great  717                    Yveltal     Dark  Flying
# 796         796     Great  719        DiancieMega Diancie     Rock   Fairy
# 797         797     Great  720        HoopaHoopa Confined  Psychic   Ghost
# 798         798     Great  720         HoopaHoopa Unbound  Psychic    Dark
# 799         799     Great  721                  Volcanion     Fire   Water
#
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed Legendary.1
# ...

# %%
pokemon_data01.groupby(["Type 1"]).mean()
# Out:
#           Unnamed: 0           #         HP      Attack     Defense  \
# Type 1
# Bug       368.072464  334.492754  56.884058   70.971014   70.724638
# Dark      507.387097  461.354839  66.806452   88.387097   70.225806
# Dragon    521.843750  474.375000  83.312500  112.125000   86.375000
# Electric  400.590909  363.500000  59.795455   69.090909   66.295455
# Fairy     494.529412  449.529412  74.117647   61.529412   65.705882
# Fighting  400.444444  363.851852  69.851852   96.777778   65.925926
# Fire      360.942308  327.403846  69.903846   84.769231   67.769231
# Flying    746.500000  677.750000  70.750000   78.750000   66.250000
# Ghost     536.281250  486.500000  64.437500   73.781250   81.187500
# Grass     380.414286  344.871429  67.271429   73.214286   70.800000
# Ground    392.312500  356.281250  73.781250   95.750000   84.843750
# Ice       465.666667  423.541667  72.000000   72.750000   71.416667
# Normal    351.581633  319.173469  77.275510   73.469388   59.846939
# ...

# %%
pokemon_data01.groupby(["Type 1"]).mean().sort_values("Attack",ascending=False)
# Out:
#           Unnamed: 0           #         HP      Attack     Defense  \
# Type 1
# Dragon    521.843750  474.375000  83.312500  112.125000   86.375000
# Fighting  400.444444  363.851852  69.851852   96.777778   65.925926
# Ground    392.312500  356.281250  73.781250   95.750000   84.843750
# Rock      431.840909  392.727273  65.363636   92.863636  100.795455
# Steel     486.296296  442.851852  65.222222   92.703704  126.370370
# Dark      507.387097  461.354839  66.806452   88.387097   70.225806
# Fire      360.942308  327.403846  69.903846   84.769231   67.769231
# Flying    746.500000  677.750000  70.750000   78.750000   66.250000
# Poison    278.285714  251.785714  67.250000   74.678571   68.821429
# Water     333.312500  303.089286  72.062500   74.151786   72.946429
# Ghost     536.281250  486.500000  64.437500   73.781250   81.187500
# Normal    351.581633  319.173469  77.275510   73.469388   59.846939
# Grass     380.414286  344.871429  67.271429   73.214286   70.800000
# ...
